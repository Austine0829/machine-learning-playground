# %%
import librosa as lb
import os
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tqdm import tqdm

dataset_path = "genres_original"

def peak_normalization(y):
    return lb.util.normalize(y)

def extract_song_feature(song_path):
    try:
        y, sr = lb.load(song_path, sr=None, duration=30)

        y = peak_normalization(y)

        mfcc = lb.feature.mfcc(y=y, sr=sr, n_mfcc=13)
        mfcc_mean = np.mean(mfcc, axis=1)
        mfcc_std = np.std(mfcc, axis=1)

        chroma_stft = np.mean(lb.feature.chroma_stft(y=y, sr=sr), axis=1)

        spectral_bandwidth = np.mean(lb.feature.spectral_bandwidth(y=y, sr=sr))
        spectral_centroid = np.mean(lb.feature.spectral_centroid(y=y, sr=sr))
        spectral_rollof = np.mean(lb.feature.spectral_rolloff(y=y, sr=sr))
        
        spectral_contrast = lb.feature.spectral_contrast(y=y, sr=sr)
        spectral_contrast_mean = np.mean(spectral_contrast, axis=1)
        spectral_contrast_std = np.std(spectral_contrast, axis=1)

        rms = np.mean(lb.feature.rms(y=y))

        tempo, _ = lb.beat.beat_track(y=y, sr=sr)

        return np.hstack([mfcc_mean, 
                          mfcc_std,
                          chroma_stft, 
                          spectral_bandwidth, 
                          spectral_centroid, 
                          spectral_rollof, 
                          spectral_contrast_mean,
                          spectral_contrast_std,
                          rms,
                          tempo]) 

    except Exception as e:
        print(f"Error has occured in song file {song_path}: {e}")
        return None

# %%
X = []
y = []

if not os.path.exists("song_dataset.csv"):
    for genre in os.listdir(dataset_path):
        genre_path = os.path.join(dataset_path, genre)
        
        for song in tqdm(os.listdir(genre_path), desc=f"Extracting song features in folder {genre}"):
            song_path = os.path.join(genre_path, song)
            song_features = extract_song_feature(song_path)

            if song_features is not None:
                X.append(song_features)
                y.append(genre)
# Out:
# Extracting song features in folder blues: 100%|██████████| 100/100 [01:28<00:00,  1.13it/s]
# Extracting song features in folder classical: 100%|██████████| 100/100 [00:42<00:00,  2.37it/s]
# Extracting song features in folder country: 100%|██████████| 100/100 [00:40<00:00,  2.49it/s]
# Extracting song features in folder disco: 100%|██████████| 100/100 [00:43<00:00,  2.28it/s]
# Extracting song features in folder hiphop: 100%|██████████| 100/100 [00:49<00:00,  2.02it/s]
# Extracting song features in folder jazz:  54%|█████▍    | 54/100 [00:35<00:44,  1.03it/s]C:\Users\Admin\AppData\Local\Temp\ipykernel_19640\1924746381.py:17: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lb.load(song_path, sr=None)
# c:\Users\Admin\desktop\machine-learning-playground\env\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Error has occured in song file genres_original\jazz\jazz.00054.wav:
# Extracting song features in folder jazz: 100%|██████████| 100/100 [01:21<00:00,  1.23it/s]
# Extracting song features in folder metal: 100%|██████████| 100/100 [01:32<00:00,  1.09it/s]
# Extracting song features in folder pop: 100%|██████████| 100/100 [00:40<00:00,  2.48it/s]
# Extracting song features in folder reggae: 100%|██████████| 100/100 [00:41<00:00,  2.44it/s]
# Extracting song features in folder rock: 100%|██████████| 100/100 [00:44<00:00,  2.23it/s]

# %%
if(not os.path.exists("song_dataset.csv")):
    X = np.array(X)
    y = np.array(y)

    df = pd.DataFrame(X)
    df["genre"] = y
    df.to_csv("song_dataset.csv", index=False)

# %%
df = pd.read_csv("song_dataset.csv")

labels = np.array(["blues", 
          "classical", 
          "country",
          "disco",
          "hiphop",
          "jazz",
          "metal",
          "pop",
          "reggae",
          "rock"])

X = df.drop(columns=["genre"])
y = df['genre'].map({"blues": 0, 
                     "classical": 1, 
                     "country": 2,
                     "disco": 3,
                     "hiphop": 4,
                     "jazz": 5,
                     "metal": 6,
                     "pop": 7,
                     "reggae": 8,
                     "rock": 9})

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, train_size=0.25)

model = XGBClassifier(n_estimators=500, max_depth=15, learning_rate=0.04)
model.fit(X_train, y_train)

preds = model.predict(X_test)

acc = accuracy_score(y_test, preds)

print("Reuslt: ", acc)
print("Preds:", labels[preds])
# Out:
# Reuslt:  0.632
# Preds: ['reggae' 'pop' 'pop' 'disco' 'country' 'country' 'hiphop' 'jazz' 'hiphop'
#  'metal' 'rock' 'metal' 'pop' 'metal' 'pop' 'country' 'reggae' 'hiphop'
#  'hiphop' 'country' 'jazz' 'disco' 'country' 'pop' 'hiphop' 'blues'
#  'classical' 'country' 'reggae' 'disco' 'blues' 'pop' 'metal' 'jazz'
#  'metal' 'metal' 'classical' 'classical' 'metal' 'rock' 'pop' 'blues'
#  'pop' 'hiphop' 'classical' 'jazz' 'country' 'pop' 'blues' 'reggae'
#  'metal' 'jazz' 'country' 'jazz' 'blues' 'hiphop' 'jazz' 'jazz' 'jazz'
#  'pop' 'metal' 'metal' 'rock' 'jazz' 'pop' 'disco' 'jazz' 'disco'
#  'country' 'jazz' 'blues' 'classical' 'metal' 'classical' 'metal' 'reggae'
#  'blues' 'pop' 'jazz' 'metal' 'country' 'jazz' 'country' 'reggae' 'disco'
#  'hiphop' 'metal' 'blues' 'hiphop' 'hiphop' 'hiphop' 'pop' 'reggae' 'jazz'
#  'pop' 'blues' 'jazz' 'reggae' 'metal' 'reggae' 'metal' 'hiphop' 'country'
#  'rock' 'jazz' 'rock' 'reggae' 'jazz' 'reggae' 'metal' 'country'
#  'classical' 'blues' 'country' 'disco' 'disco' 'jazz' 'disco' 'pop'
#  'country' 'country' 'blues' 'hiphop' 'reggae' 'disco' 'rock' 'classical'
#  'blues' 'disco' 'rock' 'disco' 'country' 'jazz' 'blues' 'classical' 'pop'
#  'jazz' 'blues' 'jazz' 'rock' 'jazz' 'disco' 'country' 'country'
#  'classical' 'reggae' 'rock' 'reggae' 'country' 'pop' 'disco' 'disco'
#  'pop' 'pop' 'country' 'metal' 'metal' 'jazz' 'hiphop' 'disco' 'jazz'
#  'jazz' 'jazz' 'metal' 'rock' 'metal' 'classical' 'reggae' 'reggae'
#  'classical' 'hiphop' 'rock' 'hiphop' 'rock' 'metal' 'pop' 'country'
#  'hiphop' 'pop' 'hiphop' 'rock' 'classical' 'pop' 'hiphop' 'rock' 'hiphop'
#  'country' 'jazz' 'rock' 'reggae' 'blues' 'reggae' 'disco' 'rock' 'disco'
#  'rock' 'blues' 'country' 'country' 'metal' 'country' 'blues' 'classical'
#  'rock' 'hiphop' 'reggae' 'rock' 'classical' 'country' 'reggae' 'reggae'
#  'pop' 'reggae' 'jazz' 'hiphop' 'blues' 'rock' 'reggae' 'hiphop' 'blues'
#  'disco' 'blues' 'blues' 'pop' 'hiphop' 'jazz' 'metal' 'blues' 'hiphop'
#  'disco' 'blues' 'blues' 'country' 'pop' 'country' 'disco' 'hiphop'
#  'country' 'hiphop' 'jazz' 'pop' 'classical' 'metal' 'disco' 'rock'
#  'hiphop' 'disco' 'blues' 'rock' 'reggae' 'reggae' 'rock' 'classical'
#  'hiphop' 'blues' 'classical' 'hiphop' 'rock' 'blues' 'reggae' 'reggae'
#  'country' 'country' 'blues' 'reggae' 'hiphop' 'reggae' 'pop' 'hiphop'
#  'reggae' 'classical' 'reggae' 'blues' 'disco' 'blues' 'classical' 'metal'
#  'disco' 'metal' 'metal' 'metal' 'country' 'country' 'pop' 'hiphop' 'rock'
#  'hiphop' 'rock' 'reggae' 'disco' 'pop' 'reggae' 'country' 'pop' 'country'
#  'rock' 'reggae' 'blues' 'classical' 'country' 'pop' 'metal' 'metal' 'pop'
#  'jazz' 'disco' 'jazz' 'rock' 'rock' 'metal' 'jazz' 'jazz' 'jazz' 'jazz'
#  'rock' 'country' 'disco' 'reggae' 'country' 'metal' 'jazz' 'disco'
#  'disco' 'rock' 'rock' 'pop' 'hiphop' 'rock' 'classical' 'disco' 'pop'
#  'blues' 'pop' 'disco' 'pop' 'rock' 'pop' 'rock' 'jazz' 'blues' 'rock'
#  'classical' 'classical' 'jazz' 'reggae' 'hiphop' 'blues' 'pop'
#  'classical' 'country' 'disco' 'blues' 'country' 'classical' 'pop'
#  'hiphop' 'disco' 'classical' 'metal' 'metal' 'classical' 'metal' 'jazz'
#  'jazz' 'metal' 'classical' 'pop' 'rock' 'classical' 'reggae' 'classical'
#  'classical' 'jazz' 'rock' 'metal' 'blues' 'metal' 'hiphop' 'country'
#  'classical' 'hiphop' 'disco' 'country' 'country' 'reggae' 'jazz' 'blues'
#  'hiphop' 'classical' 'blues' 'pop' 'classical' 'jazz' 'reggae' 'pop'
#  'hiphop' 'hiphop' 'disco' 'jazz' 'pop' 'hiphop' 'jazz' 'metal' 'metal'
#  'rock' 'disco' 'metal' 'rock' 'metal' 'rock' 'metal' 'blues' 'blues'
#  'hiphop' 'blues' 'rock' 'metal' 'pop' 'blues' 'pop' 'hiphop' 'jazz'
#  'jazz' 'rock' 'metal' 'blues' 'blues' 'country' 'country' 'disco'
#  'reggae' 'metal' 'country' 'blues' 'classical' 'disco' 'metal' 'metal'
#  'country' 'reggae' 'reggae' 'classical' 'jazz' 'rock' 'reggae'
#  'classical' 'metal' 'metal' 'jazz' 'jazz' 'blues' 'classical' 'country'
#  'metal' 'hiphop' 'metal' 'hiphop' 'country' 'disco' 'classical' 'jazz'
#  'jazz' 'disco' 'classical' 'classical' 'metal' 'country' 'pop' 'hiphop'
#  'reggae' 'pop' 'reggae' 'disco' 'rock' 'disco' 'rock' 'metal' 'pop'
#  'metal' 'blues' 'reggae' 'country' 'jazz' 'rock' 'blues' 'pop'
#  'classical' 'metal' 'rock' 'jazz' 'pop' 'classical' 'hiphop' 'classical'
#  'reggae' 'hiphop' 'reggae' 'reggae' 'metal' 'classical' 'reggae' 'metal'
#  'pop' 'rock' 'pop' 'disco' 'disco' 'metal' 'country' 'classical' 'disco'
#  'metal' 'blues' 'disco' 'pop' 'country' 'classical' 'country' 'blues'
#  'blues' 'metal' 'rock' 'disco' 'pop' 'disco' 'hiphop' 'country' 'metal'
#  'jazz' 'jazz' 'blues' 'metal' 'blues' 'reggae' 'pop' 'classical' 'hiphop'
#  'reggae' 'hiphop' 'classical' 'country' 'country' 'metal' 'classical'
#  'hiphop' 'rock' 'country' 'jazz' 'classical' 'classical' 'hiphop' 'metal'
#  'hiphop' 'metal' 'hiphop' 'rock' 'country' 'blues' 'disco' 'classical'
#  'country' 'reggae' 'pop' 'blues' 'reggae' 'country' 'disco' 'country'
#  'reggae' 'rock' 'classical' 'pop' 'blues' 'hiphop' 'jazz' 'classical'
#  'hiphop' 'disco' 'disco' 'disco' 'jazz' 'reggae' 'pop' 'reggae' 'hiphop'
#  'jazz' 'reggae' 'blues' 'classical' 'hiphop' 'reggae' 'metal' 'pop'
#  'reggae' 'country' 'blues' 'metal' 'jazz' 'metal' 'blues' 'classical'
#  'disco' 'rock' 'metal' 'rock' 'classical' 'classical' 'metal' 'metal'
#  'rock' 'rock' 'pop' 'pop' 'pop' 'metal' 'metal' 'jazz' 'country' 'blues'
#  'blues' 'jazz' 'pop' 'classical' 'reggae' 'jazz' 'blues' 'rock' 'hiphop'
#  'jazz' 'metal' 'pop' 'country' 'pop' 'metal' 'country' 'jazz' 'pop'
#  'reggae' 'rock' 'reggae' 'jazz' 'blues' 'blues' 'rock' 'hiphop' 'blues'
#  'reggae' 'pop' 'reggae' 'classical' 'reggae' 'reggae' 'jazz' 'country'
#  'reggae' 'jazz' 'blues' 'classical' 'rock' 'reggae' 'metal' 'rock' 'pop'
#  'classical' 'country' 'hiphop' 'classical' 'hiphop' 'hiphop' 'pop'
#  'reggae' 'reggae' 'metal' 'classical' 'blues' 'rock' 'hiphop' 'classical'
#  'rock' 'metal' 'classical' 'pop' 'metal' 'reggae' 'blues' 'reggae'
#  'metal' 'rock' 'rock' 'pop' 'jazz' 'metal' 'pop' 'pop' 'country' 'metal'
#  'blues' 'metal' 'classical' 'pop' 'metal' 'reggae' 'jazz' 'pop' 'hiphop'
#  'classical' 'rock' 'reggae' 'reggae' 'pop' 'metal' 'blues' 'hiphop'
#  'reggae' 'classical' 'classical' 'hiphop' 'metal' 'jazz' 'jazz'
#  'classical' 'metal' 'blues' 'country' 'disco' 'classical' 'classical'
#  'jazz' 'reggae' 'country' 'disco' 'rock' 'reggae' 'blues' 'pop' 'pop'
#  'classical' 'metal' 'reggae' 'pop' 'disco' 'pop' 'blues' 'classical'
#  'metal' 'reggae' 'pop' 'rock' 'metal' 'metal']

# %%
target_song = extract_song_feature("testing_song.mp3")
target_song = target_song.reshape(1, -1)

normalized_target_song = peak_normalization(target_song)

pred = model.predict(normalized_target_song)

print(labels[pred])
# Out:
# ['pop']
