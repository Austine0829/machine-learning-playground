# %%
import pandas as pd

names = pd.Series(['Austine', 'Audrey', 'Tuazon'], index=['a', 'b', 'c'])
names_two = pd.Series(['Feeniks', 'Maria', 'Gabriella'], index=['c', 'b', 'a'])

print(names + names_two)
# Out:
# a    AustineGabriella
# b         AudreyMaria
# c       TuazonFeeniks
# dtype: object

# %%
data = {
    'Name': ['Alice', 'Penny', 'Rakuzan'],
    'Age': [22, 12, 15]
}

data

df = pd.DataFrame(data)

df
# Out:
#       Name  Age
# 0    Alice   22
# 1    Penny   12
# 2  Rakuzan   15

# %%
df.head(2)
# Out:
#     Name  Age
# 0  Alice   22
# 1  Penny   12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
print(df['Name'])
print(df['Age'])
# Out:
# 0      Alice
# 1      Penny
# 2    Rakuzan
# Name: Name, dtype: object
# 0    22
# 1    12
# 2    15
# Name: Age, dtype: int64

# %%
df.loc[df['Age'] < 20]['Name']
# Out:
# 1      Penny
# 2    Rakuzan
# Name: Name, dtype: object

# %%
data_frame = pd.DataFrame({
    "Name": ["Ana", "Ben", "Cara", "Dan"],
    "Age": [23, 30, 27, 22],
    "City": ["Manila", "Cebu", "Davao", "Manila"]
})

data_frame[['Name', 'Age']]
# Out:
#    Name  Age
# 0   Ana   23
# 1   Ben   30
# 2  Cara   27
# 3   Dan   22

# %%
data_frame.loc[0:2, ['Name']]
# Out:
#    Name
# 0   Ana
# 1   Ben
# 2  Cara
